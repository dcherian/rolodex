# %% [markdown]
# # CRSIndex experiment
#
# Following https://hackmd.io/Zxw_zCa7Rbynx_iJu6Y3LA?view

# %%
import rioxarray
import xarray as xr

ds = xr.open_dataset(
    "/Users/dcherian/python/rioxarray/test/test_data/input/PLANET_SCOPE_3D.nc",
    # decode_coords="all",
    engine="rasterio",
)
ds
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 2, x: 10, y: 10)
# Coordinates:
#   * time         (time) object 2016-12-19 10:27:29.687763 2016-12-29 12:52:42...
#   * x            (x) float64 4.663e+05 4.663e+05 ... 4.663e+05 4.663e+05
#   * y            (y) float64 8.085e+06 8.085e+06 ... 8.085e+06 8.085e+06
#     spatial_ref  int64 ...
# Data variables:
#     blue         (time, y, x) float64 ...
#     green        (time, y, x) float64 ...
# Attributes:
#     coordinates:  spatial_ref

# %%
# check that we are on the pydata/xarray:scipy22 branch
assert hasattr(ds, "set_xindex")

# %%
from xarray.core.indexes import Index, PandasIndex
from xarray.core.indexing import IndexSelResult, merge_sel_results


def create_spatial_ref(crs_wkt):
    """Because I don't know what I'm doing"""
    return xr.Variable((), 0, attrs={"crs_wkt": crs_wkt})


class CRSIndex(Index):
    # based off Benoit's RasterIndex in
    # https://hackmd.io/Zxw_zCa7Rbynx_iJu6Y3LA?view

    def __init__(self, variables):

        # assert len(xy_indexes) == 2
        assert "x" in variables
        assert "y" in variables
        assert "spatial_ref" in variables

        # TODO: Instead do whatever the rio accessor is doing.
        # rioxarray.open_dataset is doing
        spatial_ref = variables.pop("spatial_ref")
        self._crs = rioxarray.crs.CRS.from_wkt(spatial_ref.attrs["crs_wkt"])

        # must have two distinct dimensions
        # Assumes x, y for index are never scalar. Is that correct?
        dim = [idx.dim for key, idx in variables.items()]
        assert dim[0] != dim[1]

        self._indexes = variables

    @classmethod
    def from_variables(cls, variables):
        # assert len(variables) == 2

        xy_indexes = {
            k: PandasIndex.from_variables({k: v})
            for k, v in variables.items()
            if k in ["x", "y"]
        }
        xy_indexes["spatial_ref"] = variables["spatial_ref"]

        return cls(xy_indexes)

    # TODO: variables=None?
    # set_xindex tries to pass variables

    def create_variables(self, variables=None):
        idx_variables = {}

        for index in self._indexes.values():
            idx_variables.update(index.create_variables(variables))

        idx_variables["spatial_ref"] = create_spatial_ref(self.as_wkt)
        return idx_variables

    # TODO: see notes about IndexSelResult
    #    The latter is a small class that stores positional indexers (indices)
    #    and that could also store new variables, new indexes,
    #    names of variables or indexes to drop,
    #    names of dimensions to rename, etc.
    def sel(self, labels, **kwargs):

        # sel needs to only handle keys in labels
        # since it delegates to isel.
        # we handle all entries in ._indexes there
        results = []
        for k, index in self._indexes.items():
            if k in labels:
                results.append(index.sel({k: labels[k]}, **kwargs))
        return merge_sel_results(results)

    def isel(self, indexers):
        # TODO: check dim names in indexes
        results = {}
        for k, index in self._indexes.items():
            if k in indexers:
                results[k] = index.isel({k: indexers[k]})
            else:
                results[k] = index
        # AGAIN!
        results["spatial_ref"] = create_spatial_ref(self.as_wkt)
        return type(self)(results)

    def __repr__(self):
        string = f"CRSIndex: {self._crs.to_string()}"
        return string

    def equals(self, other):
        result = (
            self._crs == other._crs
            and self._indexes["x"].equals(other._indexes["x"])
            and self._indexes["y"].equals(other._indexes["y"])
        )
        # for understanding
        print(f"--- CALLED EQUALS: returning {result}")

        return result

    def join(self, other, how="inner"):
        if self._crs != other._crs:
            raise ValueError(
                "Cannot align or join objects with different CRS. "
                f"Received {self._crs.name} and {other._crs.name}"
            )

        new_indexes = {
            k: v.join(other._indexes[k], how=how) for k, v in self._indexes.items()
        }
        # create new spatial_ref here.
        new_indexes["spatial_ref"] = create_spatial_ref(self.as_wkt)
        return type(self)(new_indexes)

    # def reindex_like(self, other, method=None, tolerance=None):
    #    pass

    @property
    def as_crs(self):
        return self._crs

    @property
    def as_wkt(self):
        return self._crs.to_wkt()

# %%
import cf_xarray as cfxr  # to show off

# TODO: maybe spatial_ref info should be kwarg to `__init__` and `from_variables`
# Could imagine just passing a CRS object directly too.
index = CRSIndex.from_variables(
    {
        "x": ds.cf["projection_x_coordinate"].variable,
        "y": ds.cf["projection_y_coordinate"].variable,
        "spatial_ref": ds["spatial_ref"].variable,
    }
)
index
# Out:
# CRSIndex: EPSG:32722

# %% [markdown]
# ## Assign CRSIndex

# %%
newds = ds.copy(deep=True)
names = ds.cf.standard_names

# had to disable an error in set_xindex
newds = newds.set_xindex(
    (
        *names["projection_x_coordinate"],
        *names["projection_y_coordinate"],
        "spatial_ref",
    ),
    CRSIndex,
)
newds

# Seems like we should delete spatial_ref
# But that is not allowed by set_xindex
# del newds["spatial_ref"] # doesn't work
# Out:
# /Users/dcherian/work/python/xarray/xarray/core/dataset.py:4163: UserWarning: This is temporary API to experiment with custom indexes
#   warnings.warn("This is temporary API to experiment with custom indexes")
# /Users/dcherian/work/python/xarray/xarray/core/dataset.py:4185: UserWarning: those coordinates already have an index: {'x', 'y'}
#   warnings.warn(
# <xarray.Dataset>
# Dimensions:      (time: 2, x: 10, y: 10)
# Coordinates:
#   * time         (time) object 2016-12-19 10:27:29.687763 2016-12-29 12:52:42...
#   * x            (x) float64 4.663e+05 4.663e+05 ... 4.663e+05 4.663e+05
#   * y            (y) float64 8.085e+06 8.085e+06 ... 8.085e+06 8.085e+06
#   * spatial_ref  int64 0
# Data variables:
#     blue         (time, y, x) float64 6.611 5.581 0.3996 ... 3.491 5.056 3.368
#     green        (time, y, x) float64 7.921 66.15 30.1 ... 21.76 27.29 18.41

# %% [markdown]
# Check that our CRSIndex has been assigned

# %%
newds.xindexes
# Out:
# Indexes:
# time: <xarray.core.indexes.PandasIndex object at 0x7ff5d8d2c810>
# x: CRSIndex: EPSG:32722
# y: CRSIndex: EPSG:32722
# spatial_ref: CRSIndex: EPSG:32722

# %% [markdown]
# ## Selection
#
# ### Vectors

# %%
#!!!!
newds.sel(x=[46670, 46675], method="nearest")
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 2, y: 10, x: 2)
# Coordinates:
#   * time         (time) object 2016-12-19 10:27:29.687763 2016-12-29 12:52:42...
#   * x            (x) float64 4.663e+05 4.663e+05
#   * y            (y) float64 8.085e+06 8.085e+06 ... 8.085e+06 8.085e+06
#   * spatial_ref  int64 0
# Data variables:
#     blue         (time, y, x) float64 6.611 6.611 4.536 ... 1.781 1.844 1.844
#     green        (time, y, x) float64 7.921 7.921 23.8 ... 16.77 44.67 44.67

# %% [markdown]
# Since `spatial_ref` is bolded, we know the index is being propagated but lets check

# %%
newds.sel(x=[46670, 46675], method="nearest").xindexes
# Out:
# Indexes:
# time: <xarray.core.indexes.PandasIndex object at 0x7ff5d8d2c810>
# x: CRSIndex: EPSG:32722
# y: CRSIndex: EPSG:32722
# spatial_ref: CRSIndex: EPSG:32722

# %% [markdown]
# ### Scalar selection

# %%
# Should scalar be supported?
newds.sel(x=46670, method="nearest")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [10], in <cell line: 2>()
#       1 # Should scalar be supported?
# ----> 2 newds.sel(x=46670, method="nearest")
#
# File ~/work/python/xarray/xarray/core/dataset.py:2553, in Dataset.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    2550                 query_results.drop_coords.append(k)
#    2551     query_results.variables = no_scalar_variables
# -> 2553 result = self.isel(indexers=query_results.dim_indexers, drop=drop)
#    2554 return result._overwrite_indexes(*query_results.as_tuple()[1:])
#
# File ~/work/python/xarray/xarray/core/dataset.py:2403, in Dataset.isel(self, indexers, drop, missing_dims, **indexers_kwargs)
#    2400 dims: dict[Hashable, int] = {}
#    2401 coord_names = self._coord_names.copy()
# -> 2403 indexes, index_variables = isel_indexes(self.xindexes, indexers)
#    2405 for name, var in self._variables.items():
#    2406     # preserve variable order
#    2407     if name in index_variables:
#
# File ~/work/python/xarray/xarray/core/indexes.py:1357, in isel_indexes(indexes, indexers)
#    1353 def isel_indexes(
#    1354     indexes: Indexes[Index],
#    1355     indexers: Mapping[Any, Any],
#    1356 ) -> tuple[dict[Hashable, Index], dict[Hashable, Variable]]:
# -> 1357     return _apply_indexes(indexes, indexers, "isel")
#
# File ~/work/python/xarray/xarray/core/indexes.py:1341, in _apply_indexes(indexes, args, func)
#    1339 index_args = {k: v for k, v in args.items() if k in index_dims}
#    1340 if index_args:
# -> 1341     new_index = getattr(index, func)(index_args)
#    1342     if new_index is not None:
#    1343         new_indexes.update({k: new_index for k in index_vars})
#
# Input In [3], in CRSIndex.isel(self, indexers)
#      82 # AGAIN!
#      83 results["spatial_ref"] = create_spatial_ref(self.as_wkt)
# ---> 84 return type(self)(results)
#
# Input In [3], in CRSIndex.__init__(self, variables)
#      24 self._crs = rioxarray.crs.CRS.from_wkt(spatial_ref.attrs["crs_wkt"])
#      26 # must have two distinct dimensions
#      27 # Assumes x, y for index are never scalar. Is that correct?
# ---> 28 dim = [idx.dim for key, idx in variables.items()]
#      29 assert dim[0] != dim[1]
#      31 self._indexes = variables
#
# Input In [3], in <listcomp>(.0)
#      24 self._crs = rioxarray.crs.CRS.from_wkt(spatial_ref.attrs["crs_wkt"])
#      26 # must have two distinct dimensions
#      27 # Assumes x, y for index are never scalar. Is that correct?
# ---> 28 dim = [idx.dim for key, idx in variables.items()]
#      29 assert dim[0] != dim[1]
#      31 self._indexes = variables
#
# AttributeError: 'NoneType' object has no attribute 'dim'

# %% [markdown]
# ## alignment
#
# ### Create a reprojected dataset that should not align

# %%
# oops lost index
reprojected = newds.rio.reproject("EPSG:4326")
reprojected.xindexes
# Out:
# Indexes:
# x: <xarray.core.indexes.PandasIndex object at 0x7ff5bb92d770>
# y: <xarray.core.indexes.PandasIndex object at 0x7ff5bb92d810>
# time: <xarray.core.indexes.PandasIndex object at 0x7ff5bb92d7c0>

# %%
# set CRSIndex again
reprojected = ds.rio.reproject("EPSG:4326").set_xindex(
    ("x", "y", "spatial_ref"), CRSIndex
)
reprojected
# Out:
# /Users/dcherian/work/python/xarray/xarray/core/dataset.py:4163: UserWarning: This is temporary API to experiment with custom indexes
#   warnings.warn("This is temporary API to experiment with custom indexes")
# /Users/dcherian/work/python/xarray/xarray/core/dataset.py:4185: UserWarning: those coordinates already have an index: {'x', 'y'}
#   warnings.warn(
# <xarray.Dataset>
# Dimensions:      (x: 10, y: 10, time: 2)
# Coordinates:
#   * time         (time) object 2016-12-19 10:27:29.687763 2016-12-29 12:52:42...
#   * x            (x) float64 -51.32 -51.32 -51.32 ... -51.32 -51.32 -51.32
#   * y            (y) float64 -17.32 -17.32 -17.32 ... -17.32 -17.32 -17.32
#   * spatial_ref  int64 0
# Data variables:
#     blue         (time, y, x) float64 6.611 5.581 0.3996 ... 3.491 5.056 3.368
#     green        (time, y, x) float64 7.921 66.15 30.1 ... 21.76 27.29 18.41

# %% [markdown]
# ### default join="outer"
#
# Note nice error message!

# %%
xr.align(reprojected, newds)
# Out:
# --- CALLED EQUALS: returning False
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [141], in <cell line: 1>()
# ----> 1 xr.align(reprojected, newds)
#
# File ~/work/python/xarray/xarray/core/alignment.py:764, in align(join, copy, indexes, exclude, fill_value, *objects)
#     568 """
#     569 Given any number of Dataset and/or DataArray objects, returns new
#     570 objects with aligned indexes and dimension sizes.
#    (...)
#     754
#     755 """
#     756 aligner = Aligner(
#     757     objects,
#     758     join=join,
#    (...)
#     762     fill_value=fill_value,
#     763 )
# --> 764 aligner.align()
#     765 return aligner.results
#
# File ~/work/python/xarray/xarray/core/alignment.py:551, in Aligner.align(self)
#     549 self.find_matching_unindexed_dims()
#     550 self.assert_no_index_conflict()
# --> 551 self.align_indexes()
#     552 self.assert_unindexed_dim_sizes_equal()
#     554 if self.join == "override":
#
# File ~/work/python/xarray/xarray/core/alignment.py:404, in Aligner.align_indexes(self)
#     397     raise ValueError(
#     398         "cannot align objects with join='exact' where "
#     399         "index/labels/sizes are not equal along "
#     400         "these coordinates (dimensions): "
#     401         + ", ".join(f"{name!r} {dims!r}" for name, dims in key[0])
#     402     )
#     403 joiner = self._get_index_joiner(index_cls)
# --> 404 joined_index = joiner(matching_indexes)
#     405 if self.join == "left":
#     406     joined_index_vars = matching_index_vars[0]
#
# Input In [133], in CRSIndex.join(self, other, how)
#      80 def join(self, other, how="inner"):
#      81     if self._crs != other._crs:
# ---> 82         raise ValueError(
#      83             "Cannot align or join objects with different CRS. "
#      84             f"Received {self._crs.name} and {other._crs.name}"
#      85         )
#      87     new_indexes = {
#      88         k: v.join(other._indexes[k], how=how) for k, v in self._indexes.items()
#      89     }
#      90     # create new spatial_ref here.
#
# ValueError: Cannot align or join objects with different CRS. Received WGS 84 and WGS 84 / UTM zone 22S

# %% [markdown]
# ### join="exact" test out __equals__
#
# Could have nicer error message

# %%
xr.align(reprojected, newds, join="exact")
# Out:
# --- CALLED EQUALS: returning False
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 xr.align(reprojected, newds, join="exact")
#
# File ~/work/python/xarray/xarray/core/alignment.py:764, in align(join, copy, indexes, exclude, fill_value, *objects)
#     568 """
#     569 Given any number of Dataset and/or DataArray objects, returns new
#     570 objects with aligned indexes and dimension sizes.
#    (...)
#     754
#     755 """
#     756 aligner = Aligner(
#     757     objects,
#     758     join=join,
#    (...)
#     762     fill_value=fill_value,
#     763 )
# --> 764 aligner.align()
#     765 return aligner.results
#
# File ~/work/python/xarray/xarray/core/alignment.py:551, in Aligner.align(self)
#     549 self.find_matching_unindexed_dims()
#     550 self.assert_no_index_conflict()
# --> 551 self.align_indexes()
#     552 self.assert_unindexed_dim_sizes_equal()
#     554 if self.join == "override":
#
# File ~/work/python/xarray/xarray/core/alignment.py:397, in Aligner.align_indexes(self)
#     395 if need_reindex:
#     396     if self.join == "exact":
# --> 397         raise ValueError(
#     398             "cannot align objects with join='exact' where "
#     399             "index/labels/sizes are not equal along "
#     400             "these coordinates (dimensions): "
#     401             + ", ".join(f"{name!r} {dims!r}" for name, dims in key[0])
#     402         )
#     403     joiner = self._get_index_joiner(index_cls)
#     404     joined_index = joiner(matching_indexes)
#
# ValueError: cannot align objects with join='exact' where index/labels/sizes are not equal along these coordinates (dimensions): 'x' ('x',), 'y' ('y',), 'spatial_ref' ()

# %% [markdown]
# ### Successfully align with a copy of itself

# %%
copy = newds.copy(deep=True)
copy.xindexes["x"]._indexes
# Out:
# {'x': <xarray.core.indexes.PandasIndex at 0x7ff5bbeb3d60>,
#  'y': <xarray.core.indexes.PandasIndex at 0x7ff5bbeb3db0>}

# %%
xr.align(copy, newds)
# Out:
# --- CALLED EQUALS: returning True
# (<xarray.Dataset>
#  Dimensions:      (time: 2, x: 10, y: 10)
#  Coordinates:
#    * time         (time) object 2016-12-19 10:27:29.687763 2016-12-29 12:52:42...
#    * x            (x) float64 4.663e+05 4.663e+05 ... 4.663e+05 4.663e+05
#    * y            (y) float64 8.085e+06 8.085e+06 ... 8.085e+06 8.085e+06
#    * spatial_ref  int64 0
#  Data variables:
#      blue         (time, y, x) float64 6.611 5.581 0.3996 ... 3.491 5.056 3.368
#      green        (time, y, x) float64 7.921 66.15 30.1 ... 21.76 27.29 18.41,
#  <xarray.Dataset>
#  Dimensions:      (time: 2, x: 10, y: 10)
#  Coordinates:
#    * time         (time) object 2016-12-19 10:27:29.687763 2016-12-29 12:52:42...
#    * x            (x) float64 4.663e+05 4.663e+05 ... 4.663e+05 4.663e+05
#    * y            (y) float64 8.085e+06 8.085e+06 ... 8.085e+06 8.085e+06
#    * spatial_ref  int64 0
#  Data variables:
#      blue         (time, y, x) float64 6.611 5.581 0.3996 ... 3.491 5.056 3.368
#      green        (time, y, x) float64 7.921 66.15 30.1 ... 21.76 27.29 18.41)

# %% [markdown]
# ### Align with subsets
#
# Needs `reindex` to be implemented

# %%
xr.align(copy.isel(x=[5, 6]), newds)
# Out:
# --- CALLED EQUALS: returning False
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 xr.align(copy.isel(x=[5, 6]), newds)
#
# File ~/work/python/xarray/xarray/core/alignment.py:764, in align(join, copy, indexes, exclude, fill_value, *objects)
#     568 """
#     569 Given any number of Dataset and/or DataArray objects, returns new
#     570 objects with aligned indexes and dimension sizes.
#    (...)
#     754
#     755 """
#     756 aligner = Aligner(
#     757     objects,
#     758     join=join,
#    (...)
#     762     fill_value=fill_value,
#     763 )
# --> 764 aligner.align()
#     765 return aligner.results
#
# File ~/work/python/xarray/xarray/core/alignment.py:557, in Aligner.align(self)
#     555     self.override_indexes()
#     556 else:
# --> 557     self.reindex_all()
#
# File ~/work/python/xarray/xarray/core/alignment.py:535, in Aligner.reindex_all(self)
#     534 def reindex_all(self) -> None:
# --> 535     self.results = tuple(
#     536         self._reindex_one(obj, matching_indexes)
#     537         for obj, matching_indexes in zip(
#     538             self.objects, self.objects_matching_indexes
#     539         )
#     540     )
#
# File ~/work/python/xarray/xarray/core/alignment.py:536, in <genexpr>(.0)
#     534 def reindex_all(self) -> None:
#     535     self.results = tuple(
# --> 536         self._reindex_one(obj, matching_indexes)
#     537         for obj, matching_indexes in zip(
#     538             self.objects, self.objects_matching_indexes
#     539         )
#     540     )
#
# File ~/work/python/xarray/xarray/core/alignment.py:520, in Aligner._reindex_one(self, obj, matching_indexes)
#     514 def _reindex_one(
#     515     self,
#     516     obj: DataAlignable,
#     517     matching_indexes: dict[MatchingIndexKey, Index],
#     518 ) -> DataAlignable:
#     519     new_indexes, new_variables = self._get_indexes_and_vars(obj, matching_indexes)
# --> 520     dim_pos_indexers = self._get_dim_pos_indexers(matching_indexes)
#     522     new_obj = obj._reindex_callback(
#     523         self,
#     524         dim_pos_indexers,
#    (...)
#     529         self.exclude_vars,
#     530     )
#     531     new_obj.encoding = obj.encoding
#
# File ~/work/python/xarray/xarray/core/alignment.py:486, in Aligner._get_dim_pos_indexers(self, matching_indexes)
#     484     if obj_idx is not None:
#     485         if self.reindex[key]:
# --> 486             indexers = obj_idx.reindex_like(aligned_idx, **self.reindex_kwargs)  # type: ignore[call-arg]
#     487             dim_pos_indexers.update(indexers)
#     489 return dim_pos_indexers
#
# File ~/work/python/xarray/xarray/core/indexes.py:92, in Index.reindex_like(self, other)
#      91 def reindex_like(self: T_Index, other: T_Index) -> dict[Hashable, Any]:
# ---> 92     raise NotImplementedError(f"{self!r} doesn't support re-indexing labels")
#
# NotImplementedError: CRSIndex: EPSG:32722 doesn't support re-indexing labels
