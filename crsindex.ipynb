# %% [markdown]
# # CRSIndex experiment
#
# Notes:
# 1. Requires `xarray==2022.10.0` for `ds.set_xindex`
# 1. Indexes are created using `Index.from_variables`. This means we have to stick everything in Variable objects.
#     - Can we support passing a CRS object directly using `**kwargs`? Not at the moment
#     - this is the data model: Indexes are constructed from a subset of Coordinate variables. all necessary information should be in a coordinate variable
#     - This demo uses `spatial_ref`, an arbitrary choice.
#
# Potential Extensions:
# - We (optionally?) want lat, lon in addition to x, y
# - potentially more fancy tree-based indexing instead of the simple Pandas based indexing here.
# - What do we do for `newds.sel(x=46670, method="nearest")` : allow a CRSIndex with only `y` and no `x`?
# - Rioxarray could assign a new index automatically when reprojecting etc.
# - better handling of various CRS options.
#
# Bug reports TODO:
# 1. flox GroupBy doesn't propagate index.
# 1. error message with `join='exact'` is very generic.

# %%
# %load_ext watermark

import cf_xarray  # to show off
import rioxarray
import xarray as xr  # need >= 2022.10.0

# %watermark -iv


ds = xr.open_dataset(
    "/Users/dcherian/python/rioxarray/test/test_data/input/PLANET_SCOPE_3D.nc",
    # decode_coords="all",
    engine="rasterio",
)

ds
# Out:
# rioxarray: 0.14.1
# cf_xarray: 0.8.2
# xarray   : 2023.6.0
# <xarray.Dataset>
# Dimensions:      (time: 2, x: 10, y: 10)
# Coordinates:
#   * time         (time) object 2016-12-19 10:27:29.687763 2016-12-29 12:52:42...
#   * x            (x) float64 4.663e+05 4.663e+05 ... 4.663e+05 4.663e+05
#   * y            (y) float64 8.085e+06 8.085e+06 ... 8.085e+06 8.085e+06
#     spatial_ref  int64 ...
# Data variables:
#     blue         (time, y, x) float64 ...
#     green        (time, y, x) float64 ...
# Attributes:
#     coordinates:  spatial_ref

# %%
from typing import Any, Hashable

from xarray.core.indexes import Index, PandasIndex, get_indexer_nd
from xarray.core.indexing import IndexSelResult, merge_sel_results


def create_spatial_ref(crs_wkt):
    """Because I don't know what I'm doing"""
    return xr.Variable((), 0, attrs={"crs_wkt": crs_wkt})


class CRSIndex(Index):
    # based off Benoit's RasterIndex in
    # https://hackmd.io/Zxw_zCa7Rbynx_iJu6Y3LA?view

    def __init__(self, variables):
        # TODO: hardcoded variable names

        # assert len(xy_indexes) == 2
        assert "x" in variables
        assert "y" in variables
        assert "spatial_ref" in variables

        # TODO: Instead do whatever the rio accessor is doing.
        # rioxarray.open_dataset is doing
        spatial_ref = variables.pop("spatial_ref")
        self._crs = rioxarray.crs.CRS.from_wkt(spatial_ref.attrs["crs_wkt"])

        # must have two distinct dimensions
        # Assumes x, y for index are never scalar. Is that correct?
        dim = [idx.dim for key, idx in variables.items()]
        assert dim[0] != dim[1]

        self._indexes = variables

    # TODO: what goes in options?
    @classmethod
    def from_variables(cls, variables, options):
        # assert len(variables) == 2

        xy_indexes = {
            k: PandasIndex.from_variables({k: v}, options=options)
            for k, v in variables.items()
            if k in ["x", "y"]
        }
        xy_indexes["spatial_ref"] = variables["spatial_ref"]

        return cls(xy_indexes)

    # TODO: variables=None?
    # set_xindex tries to pass variables; this seems like a bug
    def create_variables(self, variables=None):
        idx_variables = {}

        for index in self._indexes.values():
            idx_variables.update(index.create_variables(variables))

        idx_variables["spatial_ref"] = create_spatial_ref(self.as_wkt)
        return idx_variables

    # TODO: see notes about IndexSelResult
    #    The latter is a small class that stores positional indexers (indices)
    #    and that could also store new variables, new indexes,
    #    names of variables or indexes to drop,
    #    names of dimensions to rename, etc.
    def sel(self, labels, **kwargs):

        # sel needs to only handle keys in labels
        # since it delegates to isel.
        # we handle all entries in ._indexes there
        results = []
        for k, index in self._indexes.items():
            if k in labels:
                # defer to pandas type indexing.
                # This is where we would implement KDTree and friends
                results.append(index.sel({k: labels[k]}, **kwargs))
        return merge_sel_results(results)

    def isel(self, indexers):
        # TODO: check dim names in indexes
        results = {}
        for k, index in self._indexes.items():
            if k in indexers:
                # again possible KDTree / friends here.
                results[k] = index.isel({k: indexers[k]})
            else:
                results[k] = index
        # AGAIN!
        results["spatial_ref"] = create_spatial_ref(self.as_wkt)
        return type(self)(results)

    def __repr__(self):
        string = f"CRSIndex: {self._crs.to_string()}"
        return string

    def equals(self, other):
        result = self._crs is other._crs or (
            self._crs == other._crs
            and self._indexes["x"].equals(other._indexes["x"])
            and self._indexes["y"].equals(other._indexes["y"])
        )
        return result

    def join(self, other, how="inner"):
        if self._crs != other._crs:
            raise ValueError(
                "Cannot align or join objects with different CRS. "
                f"Received {self._crs.name!r} and {other._crs.name!r}"
            )

        new_indexes = {
            k: v.join(other._indexes[k], how=how) for k, v in self._indexes.items()
        }
        # create new spatial_ref here.
        new_indexes["spatial_ref"] = create_spatial_ref(self.as_wkt)
        return type(self)(new_indexes)

    def reindex_like(self, other, method=None, tolerance=None):
        # TODO: different method, tolerance for x, y?
        return {
            k: get_indexer_nd(
                self._indexes[k].index, other._indexes[k].index, method, tolerance
            )
            for k in self._indexes.keys()
        }

    @property
    def as_crs(self):
        return self._crs

    @property
    def as_wkt(self):
        return self._crs.to_wkt()

# %%
index = CRSIndex.from_variables(
    {
        "x": ds.cf["projection_x_coordinate"].variable,
        "y": ds.cf["projection_y_coordinate"].variable,
        "spatial_ref": ds["spatial_ref"].variable,
    },
    options={},
)
index
# Out:
# CRSIndex: EPSG:32722

# %% [markdown]
# 🎉

# %% [markdown]
# ## Assign CRSIndex to a new dataset

# %% [markdown]
# First drop the existing default PandasIndex along x, y

# %%
newds = ds.drop_indexes(["x", "y"])
newds
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 2, x: 10, y: 10)
# Coordinates:
#   * time         (time) object 2016-12-19 10:27:29.687763 2016-12-29 12:52:42...
#     x            (x) float64 4.663e+05 4.663e+05 ... 4.663e+05 4.663e+05
#     y            (y) float64 8.085e+06 8.085e+06 ... 8.085e+06 8.085e+06
#     spatial_ref  int64 0
# Data variables:
#     blue         (time, y, x) float64 ...
#     green        (time, y, x) float64 ...
# Attributes:
#     coordinates:  spatial_ref

# %% [markdown]
# Now set the new CRSIndex; note new entry under *Indexes*

# %%
names = ds.cf.standard_names
newds = newds.set_xindex(
    (
        *names["projection_x_coordinate"],
        *names["projection_y_coordinate"],
        "spatial_ref",
    ),
    CRSIndex,
)
newds

# Seems like we should delete spatial_ref
# But that is not allowed by set_xindex
# del newds["spatial_ref"] # doesn't work
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 2, x: 10, y: 10)
# Coordinates:
#   * time         (time) object 2016-12-19 10:27:29.687763 2016-12-29 12:52:42...
#   * x            (x) float64 4.663e+05 4.663e+05 ... 4.663e+05 4.663e+05
#   * y            (y) float64 8.085e+06 8.085e+06 ... 8.085e+06 8.085e+06
#   * spatial_ref  int64 0
# Data variables:
#     blue         (time, y, x) float64 ...
#     green        (time, y, x) float64 ...
# Indexes:
#     x            CRSIndex
#     y            CRSIndex
#     spatial_ref  CRSIndex
# Attributes:
#     coordinates:  spatial_ref

# %%
with xr.set_options(display_style="html"):
    display(newds)
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 2, x: 10, y: 10)
# Coordinates:
#   * time         (time) object 2016-12-19 10:27:29.687763 2016-12-29 12:52:42...
#   * x            (x) float64 4.663e+05 4.663e+05 ... 4.663e+05 4.663e+05
#   * y            (y) float64 8.085e+06 8.085e+06 ... 8.085e+06 8.085e+06
#   * spatial_ref  int64 0
# Data variables:
#     blue         (time, y, x) float64 ...
#     green        (time, y, x) float64 ...
# Indexes:
#     x            CRSIndex
#     y            CRSIndex
#     spatial_ref  CRSIndex
# Attributes:
#     coordinates:  spatial_ref

# %% [markdown]
# ^ `spatial_ref` is now bolded in the HTML repr so it is a indexed variable even though its not associated with a dimensions.

# %% [markdown]
# ## Selection
#
# ### Vectors

# %%
#!!!!
newds.sel(x=[46670, 46675], method="nearest")
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 2, y: 10, x: 2)
# Coordinates:
#   * time         (time) object 2016-12-19 10:27:29.687763 2016-12-29 12:52:42...
#   * x            (x) float64 4.663e+05 4.663e+05
#   * y            (y) float64 8.085e+06 8.085e+06 ... 8.085e+06 8.085e+06
#   * spatial_ref  int64 0
# Data variables:
#     blue         (time, y, x) float64 ...
#     green        (time, y, x) float64 ...
# Indexes:
#     x            CRSIndex
#     y            CRSIndex
#     spatial_ref  CRSIndex
# Attributes:
#     coordinates:  spatial_ref

# %% [markdown]
# ### TODO: Scalar selection
#
# This fails at the moment.
#
# What is the expected behaviour here?

# %%
# Should scalar be supported?
newds.sel(x=46670, method="nearest")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Should scalar be supported?
# ----> 2 newds.sel(x=46670, method="nearest")
#
# File ~/mambaforge/envs/xarray-release/lib/python3.10/site-packages/xarray/core/dataset.py:2667, in Dataset.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    2664                 query_results.drop_coords.append(k)
#    2665     query_results.variables = no_scalar_variables
# -> 2667 result = self.isel(indexers=query_results.dim_indexers, drop=drop)
#    2668 return result._overwrite_indexes(*query_results.as_tuple()[1:])
#
# File ~/mambaforge/envs/xarray-release/lib/python3.10/site-packages/xarray/core/dataset.py:2517, in Dataset.isel(self, indexers, drop, missing_dims, **indexers_kwargs)
#    2514 dims: dict[Hashable, int] = {}
#    2515 coord_names = self._coord_names.copy()
# -> 2517 indexes, index_variables = isel_indexes(self.xindexes, indexers)
#    2519 for name, var in self._variables.items():
#    2520     # preserve variable order
#    2521     if name in index_variables:
#
# File ~/mambaforge/envs/xarray-release/lib/python3.10/site-packages/xarray/core/indexes.py:1478, in isel_indexes(indexes, indexers)
#    1474 def isel_indexes(
#    1475     indexes: Indexes[Index],
#    1476     indexers: Mapping[Any, Any],
#    1477 ) -> tuple[dict[Hashable, Index], dict[Hashable, Variable]]:
# -> 1478     return _apply_indexes(indexes, indexers, "isel")
#
# File ~/mambaforge/envs/xarray-release/lib/python3.10/site-packages/xarray/core/indexes.py:1462, in _apply_indexes(indexes, args, func)
#    1460 index_args = {k: v for k, v in args.items() if k in index_dims}
#    1461 if index_args:
# -> 1462     new_index = getattr(index, func)(index_args)
#    1463     if new_index is not None:
#    1464         new_indexes.update({k: new_index for k in index_vars})
#
# Cell In[2], line 90, in CRSIndex.isel(self, indexers)
#      88 # AGAIN!
#      89 results["spatial_ref"] = create_spatial_ref(self.as_wkt)
# ---> 90 return type(self)(results)
#
# Cell In[2], line 31, in CRSIndex.__init__(self, variables)
#      27 self._crs = rioxarray.crs.CRS.from_wkt(spatial_ref.attrs["crs_wkt"])
#      29 # must have two distinct dimensions
#      30 # Assumes x, y for index are never scalar. Is that correct?
# ---> 31 dim = [idx.dim for key, idx in variables.items()]
#      32 assert dim[0] != dim[1]
#      34 self._indexes = variables
#
# Cell In[2], line 31, in <listcomp>(.0)
#      27 self._crs = rioxarray.crs.CRS.from_wkt(spatial_ref.attrs["crs_wkt"])
#      29 # must have two distinct dimensions
#      30 # Assumes x, y for index are never scalar. Is that correct?
# ---> 31 dim = [idx.dim for key, idx in variables.items()]
#      32 assert dim[0] != dim[1]
#      34 self._indexes = variables
#
# AttributeError: 'NoneType' object has no attribute 'dim'

# %% [markdown]
# ## Reduction

# %%
newds.mean()
# Out:
# <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#   * spatial_ref  int64 0
# Data variables:
#     blue         float64 3.52
#     green        float64 33.45
# Indexes:
#     spatial_ref  CRSIndex

# %% [markdown]
# We lose `x,y` that makes sense. `spatial_ref` is propagated, so that's great.
# - note: Bolded `spatial_ref` is confusing. A scalar index?

# %%
with xr.set_options(display_style="html"):
    display(newds.mean())
# Out:
# <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#   * spatial_ref  int64 0
# Data variables:
#     blue         float64 3.52
#     green        float64 33.45
# Indexes:
#     spatial_ref  CRSIndex

# %% [markdown]
# ## groupby with flox needs to propagate indexes.
#
# flox is worse. Not surprising.

# %%
with xr.set_options(use_flox=True):
    result = newds.groupby("time.month").mean()
result
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 with xr.set_options(use_flox=True):
# ----> 2     result = newds.groupby("time.month").mean()
#       3 result
#
# File ~/mambaforge/envs/xarray-release/lib/python3.10/site-packages/xarray/core/_aggregations.py:2962, in DatasetGroupByAggregations.mean(self, dim, skipna, keep_attrs, **kwargs)
#    2871 """
#    2872 Reduce this Dataset's data by applying ``mean`` along some dimension(s).
#    2873
#    (...)
#    2955     da       (labels) float64 nan 2.0 2.0
#    2956 """
#    2957 if (
#    2958     flox_available
#    2959     and OPTIONS["use_flox"]
#    2960     and contains_only_dask_or_numpy(self._obj)
#    2961 ):
# -> 2962     return self._flox_reduce(
#    2963         func="mean",
#    2964         dim=dim,
#    2965         skipna=skipna,
#    2966         numeric_only=True,
#    2967         # fill_value=fill_value,
#    2968         keep_attrs=keep_attrs,
#    2969         **kwargs,
#    2970     )
#    2971 else:
#    2972     return self.reduce(
#    2973         duck_array_ops.mean,
#    2974         dim=dim,
#    (...)
#    2978         **kwargs,
#    2979     )
#
# File ~/mambaforge/envs/xarray-release/lib/python3.10/site-packages/xarray/core/groupby.py:1018, in GroupBy._flox_reduce(self, dim, keep_attrs, **kwargs)
#    1015     kwargs.setdefault("min_count", 1)
#    1017 output_index = grouper.full_index
# -> 1018 result = xarray_reduce(
#    1019     obj.drop_vars(non_numeric.keys()),
#    1020     self._codes,
#    1021     dim=parsed_dim,
#    1022     # pass RangeIndex as a hint to flox that `by` is already factorized
#    1023     expected_groups=(pd.RangeIndex(len(output_index)),),
#    1024     isbin=False,
#    1025     keep_attrs=keep_attrs,
#    1026     **kwargs,
#    1027 )
#    1029 # we did end up reducing over dimension(s) that are
#    1030 # in the grouped variable
#    1031 group_dims = grouper.group.dims
#
# File ~/mambaforge/envs/xarray-release/lib/python3.10/site-packages/flox/xarray.py:471, in xarray_reduce(obj, func, expected_groups, isbin, sort, dim, fill_value, dtype, method, engine, keep_attrs, skipna, min_count, reindex, *by, **finalize_kwargs)
#     467     actual = actual.drop_vars(name)
#     468 # When grouping by MultiIndex, expect is an pd.Index wrapping
#     469 # an object array of tuples
#     470 if (
# --> 471     name in ds_broad.indexes
#     472     and isinstance(ds_broad.indexes[name], pd.MultiIndex)
#     473     and not isinstance(expect, pd.RangeIndex)
#     474 ):
#     475     levelnames = ds_broad.indexes[name].names
#     476     expect = pd.MultiIndex.from_tuples(expect.values, names=levelnames)
#
# File ~/mambaforge/envs/xarray-release/lib/python3.10/site-packages/xarray/core/dataset.py:1718, in Dataset.indexes(self)
#    1706 @property
#    1707 def indexes(self) -> Indexes[pd.Index]:
#    1708     """Mapping of pandas.Index objects used for label based indexing.
#    1709
#    1710     Raises an error if this Dataset has indexes that cannot be coerced
#    (...)
#    1716
#    1717     """
# -> 1718     return self.xindexes.to_pandas_indexes()
#
# File ~/mambaforge/envs/xarray-release/lib/python3.10/site-packages/xarray/core/indexes.py:1284, in Indexes.to_pandas_indexes(self)
#    1282         indexes[k] = idx
#    1283     elif isinstance(idx, Index):
# -> 1284         indexes[k] = idx.to_pandas_index()
#    1286 return Indexes(indexes, self._variables)
#
# File ~/mambaforge/envs/xarray-release/lib/python3.10/site-packages/xarray/core/indexes.py:84, in Index.to_pandas_index(self)
#      76 def to_pandas_index(self) -> pd.Index:
#      77     """Cast this xarray index to a pandas.Index object or raise a TypeError
#      78     if this is not supported.
#      79
#    (...)
#      82
#      83     """
# ---> 84     raise TypeError(f"{self!r} cannot be cast to a pandas.Index object")
#
# TypeError: CRSIndex: EPSG:32722 cannot be cast to a pandas.Index object

# %%
with xr.set_options(use_flox=False):
    result = newds.groupby("time.month").mean()
result
# Out:
# <xarray.Dataset>
# Dimensions:      (month: 1, y: 10, x: 10)
# Coordinates:
#   * x            (x) float64 4.663e+05 4.663e+05 ... 4.663e+05 4.663e+05
#   * y            (y) float64 8.085e+06 8.085e+06 ... 8.085e+06 8.085e+06
#   * spatial_ref  int64 0
#   * month        (month) int64 12
# Data variables:
#     blue         (month, y, x) float64 6.427 5.988 0.851 ... 4.296 3.538 2.725
#     green        (month, y, x) float64 17.03 41.3 17.3 ... 35.93 42.39 35.6
# Indexes:
#     x            CRSIndex
#     y            CRSIndex
#     spatial_ref  CRSIndex
# Attributes:
#     coordinates:  spatial_ref

# %% [markdown]
# ## alignment
#
# ### Create a reprojected dataset that should not align

# %%
# oops lost index
reprojected = newds.rio.reproject("EPSG:4326")
reprojected
# Out:
# <xarray.Dataset>
# Dimensions:      (x: 10, y: 10, time: 2)
# Coordinates:
#   * x            (x) float64 -51.32 -51.32 -51.32 ... -51.32 -51.32 -51.32
#   * y            (y) float64 -17.32 -17.32 -17.32 ... -17.32 -17.32 -17.32
#   * time         (time) object 2016-12-19 10:27:29.687763 2016-12-29 12:52:42...
#     spatial_ref  int64 0
# Data variables:
#     blue         (time, y, x) float64 6.611 5.581 0.3996 ... 3.491 5.056 3.368
#     green        (time, y, x) float64 7.921 66.15 30.1 ... 21.76 27.29 18.41
# Attributes:
#     coordinates:  spatial_ref

# %%
# set CRSIndex again; RIO could do this automatically
reprojected = (
    ds.rio.reproject("EPSG:4326")
    .drop_indexes(["x", "y"])
    .set_xindex(("x", "y", "spatial_ref"), CRSIndex)
)
reprojected
# Out:
# <xarray.Dataset>
# Dimensions:      (x: 10, y: 10, time: 2)
# Coordinates:
#   * time         (time) object 2016-12-19 10:27:29.687763 2016-12-29 12:52:42...
#   * x            (x) float64 -51.32 -51.32 -51.32 ... -51.32 -51.32 -51.32
#   * y            (y) float64 -17.32 -17.32 -17.32 ... -17.32 -17.32 -17.32
#   * spatial_ref  int64 0
# Data variables:
#     blue         (time, y, x) float64 6.611 5.581 0.3996 ... 3.491 5.056 3.368
#     green        (time, y, x) float64 7.921 66.15 30.1 ... 21.76 27.29 18.41
# Indexes:
#     x            CRSIndex
#     y            CRSIndex
#     spatial_ref  CRSIndex
# Attributes:
#     coordinates:  spatial_ref

# %% [markdown]
# ### default join="outer"
#
# Note nice error message!

# %%
xr.align(reprojected, newds)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 xr.align(reprojected, newds)
#
# File ~/mambaforge/envs/xarray-release/lib/python3.10/site-packages/xarray/core/alignment.py:787, in align(join, copy, indexes, exclude, fill_value, *objects)
#     591 """
#     592 Given any number of Dataset and/or DataArray objects, returns new
#     593 objects with aligned indexes and dimension sizes.
#    (...)
#     777
#     778 """
#     779 aligner = Aligner(
#     780     objects,
#     781     join=join,
#    (...)
#     785     fill_value=fill_value,
#     786 )
# --> 787 aligner.align()
#     788 return aligner.results
#
# File ~/mambaforge/envs/xarray-release/lib/python3.10/site-packages/xarray/core/alignment.py:572, in Aligner.align(self)
#     570 self.find_matching_unindexed_dims()
#     571 self.assert_no_index_conflict()
# --> 572 self.align_indexes()
#     573 self.assert_unindexed_dim_sizes_equal()
#     575 if self.join == "override":
#
# File ~/mambaforge/envs/xarray-release/lib/python3.10/site-packages/xarray/core/alignment.py:424, in Aligner.align_indexes(self)
#     417     raise ValueError(
#     418         "cannot align objects with join='exact' where "
#     419         "index/labels/sizes are not equal along "
#     420         "these coordinates (dimensions): "
#     421         + ", ".join(f"{name!r} {dims!r}" for name, dims in key[0])
#     422     )
#     423 joiner = self._get_index_joiner(index_cls)
# --> 424 joined_index = joiner(matching_indexes)
#     425 if self.join == "left":
#     426     joined_index_vars = matching_index_vars[0]
#
# Cell In[2], line 106, in CRSIndex.join(self, other, how)
#     104 def join(self, other, how="inner"):
#     105     if self._crs != other._crs:
# --> 106         raise ValueError(
#     107             "Cannot align or join objects with different CRS. "
#     108             f"Received {self._crs.name!r} and {other._crs.name!r}"
#     109         )
#     111     new_indexes = {
#     112         k: v.join(other._indexes[k], how=how) for k, v in self._indexes.items()
#     113     }
#     114     # create new spatial_ref here.
#
# ValueError: Cannot align or join objects with different CRS. Received 'WGS 84' and 'WGS 84 / UTM zone 22S'

# %% [markdown]
# ### join="exact" test out __equals__
#
# Could have nicer error message

# %%
xr.align(reprojected, newds, join="exact")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 xr.align(reprojected, newds, join="exact")
#
# File ~/mambaforge/envs/xarray-release/lib/python3.10/site-packages/xarray/core/alignment.py:787, in align(join, copy, indexes, exclude, fill_value, *objects)
#     591 """
#     592 Given any number of Dataset and/or DataArray objects, returns new
#     593 objects with aligned indexes and dimension sizes.
#    (...)
#     777
#     778 """
#     779 aligner = Aligner(
#     780     objects,
#     781     join=join,
#    (...)
#     785     fill_value=fill_value,
#     786 )
# --> 787 aligner.align()
#     788 return aligner.results
#
# File ~/mambaforge/envs/xarray-release/lib/python3.10/site-packages/xarray/core/alignment.py:572, in Aligner.align(self)
#     570 self.find_matching_unindexed_dims()
#     571 self.assert_no_index_conflict()
# --> 572 self.align_indexes()
#     573 self.assert_unindexed_dim_sizes_equal()
#     575 if self.join == "override":
#
# File ~/mambaforge/envs/xarray-release/lib/python3.10/site-packages/xarray/core/alignment.py:417, in Aligner.align_indexes(self)
#     415 if need_reindex:
#     416     if self.join == "exact":
# --> 417         raise ValueError(
#     418             "cannot align objects with join='exact' where "
#     419             "index/labels/sizes are not equal along "
#     420             "these coordinates (dimensions): "
#     421             + ", ".join(f"{name!r} {dims!r}" for name, dims in key[0])
#     422         )
#     423     joiner = self._get_index_joiner(index_cls)
#     424     joined_index = joiner(matching_indexes)
#
# ValueError: cannot align objects with join='exact' where index/labels/sizes are not equal along these coordinates (dimensions): 'x' ('x',), 'y' ('y',), 'spatial_ref' ()

# %% [markdown]
# ### Successfully align with a copy of itself

# %%
copy = newds.copy(deep=True)
copy
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 2, x: 10, y: 10)
# Coordinates:
#   * time         (time) object 2016-12-19 10:27:29.687763 2016-12-29 12:52:42...
#   * x            (x) float64 4.663e+05 4.663e+05 ... 4.663e+05 4.663e+05
#   * y            (y) float64 8.085e+06 8.085e+06 ... 8.085e+06 8.085e+06
#   * spatial_ref  int64 0
# Data variables:
#     blue         (time, y, x) float64 6.611 5.581 0.3996 ... 3.491 5.056 3.368
#     green        (time, y, x) float64 7.921 66.15 30.1 ... 21.76 27.29 18.41
# Indexes:
#     x            CRSIndex
#     y            CRSIndex
#     spatial_ref  CRSIndex
# Attributes:
#     coordinates:  spatial_ref

# %%
xr.align(copy, newds)
# Out:
# (<xarray.Dataset>
#  Dimensions:      (time: 2, x: 10, y: 10)
#  Coordinates:
#    * time         (time) object 2016-12-19 10:27:29.687763 2016-12-29 12:52:42...
#    * x            (x) float64 4.663e+05 4.663e+05 ... 4.663e+05 4.663e+05
#    * y            (y) float64 8.085e+06 8.085e+06 ... 8.085e+06 8.085e+06
#    * spatial_ref  int64 0
#  Data variables:
#      blue         (time, y, x) float64 6.611 5.581 0.3996 ... 3.491 5.056 3.368
#      green        (time, y, x) float64 7.921 66.15 30.1 ... 21.76 27.29 18.41
#  Indexes:
#      x            CRSIndex
#      y            CRSIndex
#      spatial_ref  CRSIndex
#  Attributes:
#      coordinates:  spatial_ref,
#  <xarray.Dataset>
#  Dimensions:      (time: 2, x: 10, y: 10)
#  Coordinates:
#    * time         (time) object 2016-12-19 10:27:29.687763 2016-12-29 12:52:42...
#    * x            (x) float64 4.663e+05 4.663e+05 ... 4.663e+05 4.663e+05
#    * y            (y) float64 8.085e+06 8.085e+06 ... 8.085e+06 8.085e+06
#    * spatial_ref  int64 0
#  Data variables:
#      blue         (time, y, x) float64 6.611 5.581 0.3996 ... 3.491 5.056 3.368
#      green        (time, y, x) float64 7.921 66.15 30.1 ... 21.76 27.29 18.41
#  Indexes:
#      x            CRSIndex
#      y            CRSIndex
#      spatial_ref  CRSIndex
#  Attributes:
#      coordinates:  spatial_ref)

# %% [markdown]
# ### Align with subsets

# %%
xr.align(newds.isel(x=[5, 6]), newds, join="outer")
# Out:
# (<xarray.Dataset>
#  Dimensions:      (time: 2, x: 10, y: 10)
#  Coordinates:
#    * time         (time) object 2016-12-19 10:27:29.687763 2016-12-29 12:52:42...
#    * x            (x) float64 4.663e+05 4.663e+05 ... 4.663e+05 4.663e+05
#    * y            (y) float64 8.085e+06 8.085e+06 ... 8.085e+06 8.085e+06
#    * spatial_ref  int64 0
#  Data variables:
#      blue         (time, y, x) float64 nan nan nan nan nan ... 1.888 nan nan nan
#      green        (time, y, x) float64 nan nan nan nan nan ... 12.96 nan nan nan
#  Indexes:
#      x            CRSIndex
#      y            CRSIndex
#      spatial_ref  CRSIndex
#  Attributes:
#      coordinates:  spatial_ref,
#  <xarray.Dataset>
#  Dimensions:      (time: 2, x: 10, y: 10)
#  Coordinates:
#    * time         (time) object 2016-12-19 10:27:29.687763 2016-12-29 12:52:42...
#    * x            (x) float64 4.663e+05 4.663e+05 ... 4.663e+05 4.663e+05
#    * y            (y) float64 8.085e+06 8.085e+06 ... 8.085e+06 8.085e+06
#    * spatial_ref  int64 0
#  Data variables:
#      blue         (time, y, x) float64 6.611 5.581 0.3996 ... 3.491 5.056 3.368
#      green        (time, y, x) float64 7.921 66.15 30.1 ... 21.76 27.29 18.41
#  Indexes:
#      x            CRSIndex
#      y            CRSIndex
#      spatial_ref  CRSIndex
#  Attributes:
#      coordinates:  spatial_ref)

# %%
xr.align(newds.isel(x=[5, 6]), newds, join="inner")
# Out:
# (<xarray.Dataset>
#  Dimensions:      (time: 2, x: 2, y: 10)
#  Coordinates:
#    * time         (time) object 2016-12-19 10:27:29.687763 2016-12-29 12:52:42...
#    * x            (x) float64 4.663e+05 4.663e+05
#    * y            (y) float64 8.085e+06 8.085e+06 ... 8.085e+06 8.085e+06
#    * spatial_ref  int64 0
#  Data variables:
#      blue         (time, y, x) float64 4.76 5.078 3.228 ... 3.218 4.871 1.888
#      green        (time, y, x) float64 11.54 14.43 44.91 ... 50.6 48.73 12.96
#  Indexes:
#      x            CRSIndex
#      y            CRSIndex
#      spatial_ref  CRSIndex
#  Attributes:
#      coordinates:  spatial_ref,
#  <xarray.Dataset>
#  Dimensions:      (time: 2, x: 2, y: 10)
#  Coordinates:
#    * time         (time) object 2016-12-19 10:27:29.687763 2016-12-29 12:52:42...
#    * x            (x) float64 4.663e+05 4.663e+05
#    * y            (y) float64 8.085e+06 8.085e+06 ... 8.085e+06 8.085e+06
#    * spatial_ref  int64 0
#  Data variables:
#      blue         (time, y, x) float64 4.76 5.078 3.228 ... 3.218 4.871 1.888
#      green        (time, y, x) float64 11.54 14.43 44.91 ... 50.6 48.73 12.96
#  Indexes:
#      x            CRSIndex
#      y            CRSIndex
#      spatial_ref  CRSIndex
#  Attributes:
#      coordinates:  spatial_ref)

# %%
xr.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit: None
# python: 3.10.12 | packaged by conda-forge | (main, Jun 23 2023, 22:39:40) [Clang 15.0.7 ]
# python-bits: 64
# OS: Darwin
# OS-release: 22.5.0
# machine: x86_64
# processor: i386
# byteorder: little
# LC_ALL: None
# LANG: en_US.UTF-8
# LOCALE: ('en_US', 'UTF-8')
# libhdf5: 1.12.2
# libnetcdf: 4.9.1
#
# xarray: 2023.6.0
# pandas: 2.0.3
# numpy: 1.24.4
# scipy: 1.11.1
# netCDF4: 1.6.3
# pydap: None
# h5netcdf: 1.2.0
# h5py: 3.8.0
# Nio: None
# zarr: 2.15.0
# cftime: 1.6.2
# nc_time_axis: 1.4.1
# PseudoNetCDF: 3.2.2
# iris: 3.4.1
# bottleneck: 1.3.7
# dask: 2023.6.1
# distributed: 2023.6.1
# matplotlib: 3.7.1
# cartopy: 0.21.1
# seaborn: 0.12.2
# numbagg: 0.2.1
# fsspec: 2023.6.0
# cupy: None
# pint: 0.22
# sparse: 0.14.0
# flox: 0.7.2
# numpy_groupies: 0.9.22
# setuptools: 68.0.0
# pip: 23.1.2
# conda: None
# pytest: 7.4.0
# mypy: None
# IPython: 8.14.0
# sphinx: None
# /Users/dcherian/mambaforge/envs/xarray-release/lib/python3.10/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
