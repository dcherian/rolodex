# %% [markdown]
# # CRSIndex experiment
#
# Following https://hackmd.io/Zxw_zCa7Rbynx_iJu6Y3LA?view
#
# Notes:
# 1. This requires the `pydata/xarray:scipy22` branch.
#     - I pushed a commit to that branch so that it prints a warning instead of raising an error when an index already exists.
#     - We need a drop_indexes
# 1. Indexes are created using `Index.from_variables`. This means we have to stick everything in Variable objects.
#     - Can we support passing a CRS object directly using `**kwargs`? Not at the moment
#     - this is the data model: Indexes are constructed from a subset of Coordinate variables. all necessary information should be in a coordinate variable
#     - This demo uses `spatial_ref`, an arbitrary choice.
#
# Potential Extensions:
# - We (optionally?) want lat, lon in addition to x, y
# - potentially more fancy tree-based indexing instead of the simple Pandas based indexing here.
# - What do we do for `newds.sel(x=46670, method="nearest")` : allow a CRSIndex with only `y` and no `x`?
# - Rioxarray could assign a new index automatically when reprojecting etc.
# - better handling of various CRS options.
#
# Bug reports TODO:
# 1. `Index.create_variables`. `set_xindex` tries to pass a `variables` kwarg but other methods don't. Semes like a bug.
# 2. How do we delete an existing index?
# 3. GroupBy doesn't propagate index.
# 4. error message with `join='exact'` is very generic.

# %%
# %load_ext watermark

import cf_xarray  # to show off
import rioxarray
import xarray as xr  # need 2022.10.0
# %watermark -iv

# indexes only shown in text repr at the moment
xr.set_options(display_style="text")

ds = xr.open_dataset(
    "/Users/dcherian/python/rioxarray/test/test_data/input/PLANET_SCOPE_3D.nc",
    # decode_coords="all",
    engine="rasterio",
)

ds
# Out:
# cf_xarray: 0.7.4
# xarray   : 2022.10.0
# rioxarray: 0.12.2
# <xarray.Dataset>
# Dimensions:      (time: 2, x: 10, y: 10)
# Coordinates:
#   * time         (time) object 2016-12-19 10:27:29.687763 2016-12-29 12:52:42...
#   * x            (x) float64 4.663e+05 4.663e+05 ... 4.663e+05 4.663e+05
#   * y            (y) float64 8.085e+06 8.085e+06 ... 8.085e+06 8.085e+06
#     spatial_ref  int64 ...
# Data variables:
#     blue         (time, y, x) float64 ...
#     green        (time, y, x) float64 ...
# Attributes:
#     coordinates:  spatial_ref

# %%
from typing import Any, Hashable

from xarray.core.indexes import Index, PandasIndex, get_indexer_nd
from xarray.core.indexing import IndexSelResult, merge_sel_results


def create_spatial_ref(crs_wkt):
    """Because I don't know what I'm doing"""
    return xr.Variable((), 0, attrs={"crs_wkt": crs_wkt})


class CRSIndex(Index):
    # based off Benoit's RasterIndex in
    # https://hackmd.io/Zxw_zCa7Rbynx_iJu6Y3LA?view

    def __init__(self, variables):
        # TODO: hardcoded variable names

        # assert len(xy_indexes) == 2
        assert "x" in variables
        assert "y" in variables
        assert "spatial_ref" in variables

        # TODO: Instead do whatever the rio accessor is doing.
        # rioxarray.open_dataset is doing
        spatial_ref = variables.pop("spatial_ref")
        self._crs = rioxarray.crs.CRS.from_wkt(spatial_ref.attrs["crs_wkt"])

        # must have two distinct dimensions
        # Assumes x, y for index are never scalar. Is that correct?
        dim = [idx.dim for key, idx in variables.items()]
        assert dim[0] != dim[1]

        self._indexes = variables

    # TODO: what goes in options?
    @classmethod
    def from_variables(cls, variables, options):
        # assert len(variables) == 2

        xy_indexes = {
            k: PandasIndex.from_variables({k: v}, options=options)
            for k, v in variables.items()
            if k in ["x", "y"]
        }
        xy_indexes["spatial_ref"] = variables["spatial_ref"]

        return cls(xy_indexes)

    # TODO: variables=None?
    # set_xindex tries to pass variables; this seems like a bug
    def create_variables(self, variables=None):
        idx_variables = {}

        for index in self._indexes.values():
            idx_variables.update(index.create_variables(variables))

        idx_variables["spatial_ref"] = create_spatial_ref(self.as_wkt)
        return idx_variables

    # TODO: see notes about IndexSelResult
    #    The latter is a small class that stores positional indexers (indices)
    #    and that could also store new variables, new indexes,
    #    names of variables or indexes to drop,
    #    names of dimensions to rename, etc.
    def sel(self, labels, **kwargs):

        # sel needs to only handle keys in labels
        # since it delegates to isel.
        # we handle all entries in ._indexes there
        results = []
        for k, index in self._indexes.items():
            if k in labels:
                # defer to pandas type indexing.
                # This is where we would implement KDTree and friends
                results.append(index.sel({k: labels[k]}, **kwargs))
        return merge_sel_results(results)

    def isel(self, indexers):
        # TODO: check dim names in indexes
        results = {}
        for k, index in self._indexes.items():
            if k in indexers:
                # again possible KDTree / friends here.
                results[k] = index.isel({k: indexers[k]})
            else:
                results[k] = index
        # AGAIN!
        results["spatial_ref"] = create_spatial_ref(self.as_wkt)
        return type(self)(results)

    def __repr__(self):
        string = f"CRSIndex: {self._crs.to_string()}"
        return string

    def equals(self, other):
        result = self._crs is other._crs or (
            self._crs == other._crs
            and self._indexes["x"].equals(other._indexes["x"])
            and self._indexes["y"].equals(other._indexes["y"])
        )
        return result

    def join(self, other, how="inner"):
        if self._crs != other._crs:
            raise ValueError(
                "Cannot align or join objects with different CRS. "
                f"Received {self._crs.name!r} and {other._crs.name!r}"
            )

        new_indexes = {
            k: v.join(other._indexes[k], how=how) for k, v in self._indexes.items()
        }
        # create new spatial_ref here.
        new_indexes["spatial_ref"] = create_spatial_ref(self.as_wkt)
        return type(self)(new_indexes)

    def reindex_like(self, other, method=None, tolerance=None):
        # TODO: different method, tolerance for x, y?
        return {
            k: get_indexer_nd(
                self._indexes[k].index, other._indexes[k].index, method, tolerance
            )
            for k in self._indexes.keys()
        }

    @property
    def as_crs(self):
        return self._crs

    @property
    def as_wkt(self):
        return self._crs.to_wkt()

# %%
index = CRSIndex.from_variables(
    {
        "x": ds.cf["projection_x_coordinate"].variable,
        "y": ds.cf["projection_y_coordinate"].variable,
        "spatial_ref": ds["spatial_ref"].variable,
    },
    options={},
)
index
# Out:
# CRSIndex: EPSG:32722

# %% [markdown]
# 🎉

# %% [markdown]
# ## Assign CRSIndex to a new dataset

# %% [markdown]
# First drop the existing default PandasIndex along x, y

# %%
newds = ds.drop_indexes(["x", "y"])
newds
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 2, x: 10, y: 10)
# Coordinates:
#   * time         (time) object 2016-12-19 10:27:29.687763 2016-12-29 12:52:42...
#     x            (x) float64 4.663e+05 4.663e+05 ... 4.663e+05 4.663e+05
#     y            (y) float64 8.085e+06 8.085e+06 ... 8.085e+06 8.085e+06
#     spatial_ref  int64 0
# Data variables:
#     blue         (time, y, x) float64 ...
#     green        (time, y, x) float64 ...
# Attributes:
#     coordinates:  spatial_ref

# %% [markdown]
# Now set the new CRSIndex; note new entry under *Indexes*

# %%
names = ds.cf.standard_names
newds = newds.set_xindex(
    (
        *names["projection_x_coordinate"],
        *names["projection_y_coordinate"],
        "spatial_ref",
    ),
    CRSIndex,
)
newds

# Seems like we should delete spatial_ref
# But that is not allowed by set_xindex
# del newds["spatial_ref"] # doesn't work
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 2, x: 10, y: 10)
# Coordinates:
#   * time         (time) object 2016-12-19 10:27:29.687763 2016-12-29 12:52:42...
#   * x            (x) float64 4.663e+05 4.663e+05 ... 4.663e+05 4.663e+05
#   * y            (y) float64 8.085e+06 8.085e+06 ... 8.085e+06 8.085e+06
#   * spatial_ref  int64 0
# Data variables:
#     blue         (time, y, x) float64 ...
#     green        (time, y, x) float64 ...
# Indexes:
#     x            CRSIndex: EPSG:32722
#     y            CRSIndex: EPSG:32722
#     spatial_ref  CRSIndex: EPSG:32722
# Attributes:
#     coordinates:  spatial_ref

# %%
with xr.set_options(display_style="html"):
    display(newds)
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 2, x: 10, y: 10)
# Coordinates:
#   * time         (time) object 2016-12-19 10:27:29.687763 2016-12-29 12:52:42...
#   * x            (x) float64 4.663e+05 4.663e+05 ... 4.663e+05 4.663e+05
#   * y            (y) float64 8.085e+06 8.085e+06 ... 8.085e+06 8.085e+06
#   * spatial_ref  int64 0
# Data variables:
#     blue         (time, y, x) float64 ...
#     green        (time, y, x) float64 ...
# Indexes:
#     x            CRSIndex: EPSG:32722
#     y            CRSIndex: EPSG:32722
#     spatial_ref  CRSIndex: EPSG:32722
# Attributes:
#     coordinates:  spatial_ref

# %% [markdown]
# ^ `spatial_ref` is now bolded in the HTML repr so it is a indexed variable even though its not associated with a dimensions.

# %% [markdown]
# ## Selection
#
# ### Vectors

# %%
#!!!!
newds.sel(x=[46670, 46675], method="nearest")
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 2, y: 10, x: 2)
# Coordinates:
#   * time         (time) object 2016-12-19 10:27:29.687763 2016-12-29 12:52:42...
#   * x            (x) float64 4.663e+05 4.663e+05
#   * y            (y) float64 8.085e+06 8.085e+06 ... 8.085e+06 8.085e+06
#   * spatial_ref  int64 0
# Data variables:
#     blue         (time, y, x) float64 6.611 6.611 4.536 ... 1.781 1.844 1.844
#     green        (time, y, x) float64 7.921 7.921 23.8 ... 16.77 44.67 44.67
# Indexes:
#     x            CRSIndex: EPSG:32722
#     y            CRSIndex: EPSG:32722
#     spatial_ref  CRSIndex: EPSG:32722
# Attributes:
#     coordinates:  spatial_ref

# %% [markdown]
# ### TODO: Scalar selection
#
# This fails at the moment.
#
# What is the expected behaviour here?

# %%
# Should scalar be supported?
newds.sel(x=46670, method="nearest")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [8], line 2
#       1 # Should scalar be supported?
# ----> 2 newds.sel(x=46670, method="nearest")
#
# File ~/mambaforge/envs/xarray-release/lib/python3.10/site-packages/xarray/core/dataset.py:2564, in Dataset.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    2561                 query_results.drop_coords.append(k)
#    2562     query_results.variables = no_scalar_variables
# -> 2564 result = self.isel(indexers=query_results.dim_indexers, drop=drop)
#    2565 return result._overwrite_indexes(*query_results.as_tuple()[1:])
#
# File ~/mambaforge/envs/xarray-release/lib/python3.10/site-packages/xarray/core/dataset.py:2414, in Dataset.isel(self, indexers, drop, missing_dims, **indexers_kwargs)
#    2411 dims: dict[Hashable, int] = {}
#    2412 coord_names = self._coord_names.copy()
# -> 2414 indexes, index_variables = isel_indexes(self.xindexes, indexers)
#    2416 for name, var in self._variables.items():
#    2417     # preserve variable order
#    2418     if name in index_variables:
#
# File ~/mambaforge/envs/xarray-release/lib/python3.10/site-packages/xarray/core/indexes.py:1441, in isel_indexes(indexes, indexers)
#    1437 def isel_indexes(
#    1438     indexes: Indexes[Index],
#    1439     indexers: Mapping[Any, Any],
#    1440 ) -> tuple[dict[Hashable, Index], dict[Hashable, Variable]]:
# -> 1441     return _apply_indexes(indexes, indexers, "isel")
#
# File ~/mambaforge/envs/xarray-release/lib/python3.10/site-packages/xarray/core/indexes.py:1425, in _apply_indexes(indexes, args, func)
#    1423 index_args = {k: v for k, v in args.items() if k in index_dims}
#    1424 if index_args:
# -> 1425     new_index = getattr(index, func)(index_args)
#    1426     if new_index is not None:
#    1427         new_indexes.update({k: new_index for k in index_vars})
#
# Cell In [2], line 90, in CRSIndex.isel(self, indexers)
#      88 # AGAIN!
#      89 results["spatial_ref"] = create_spatial_ref(self.as_wkt)
# ---> 90 return type(self)(results)
#
# Cell In [2], line 31, in CRSIndex.__init__(self, variables)
#      27 self._crs = rioxarray.crs.CRS.from_wkt(spatial_ref.attrs["crs_wkt"])
#      29 # must have two distinct dimensions
#      30 # Assumes x, y for index are never scalar. Is that correct?
# ---> 31 dim = [idx.dim for key, idx in variables.items()]
#      32 assert dim[0] != dim[1]
#      34 self._indexes = variables
#
# Cell In [2], line 31, in <listcomp>(.0)
#      27 self._crs = rioxarray.crs.CRS.from_wkt(spatial_ref.attrs["crs_wkt"])
#      29 # must have two distinct dimensions
#      30 # Assumes x, y for index are never scalar. Is that correct?
# ---> 31 dim = [idx.dim for key, idx in variables.items()]
#      32 assert dim[0] != dim[1]
#      34 self._indexes = variables
#
# AttributeError: 'NoneType' object has no attribute 'dim'

# %% [markdown]
# ## Reduction

# %%
newds.mean()
# Out:
# <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#   * spatial_ref  int64 0
# Data variables:
#     blue         float64 3.52
#     green        float64 33.45
# Indexes:
#     spatial_ref  CRSIndex: EPSG:32722

# %% [markdown]
# We lose `x,y` that makes sense. `spatial_ref` is propagated, so that's great.
# - note: Bolded `spatial_ref` is confusing. A scalar index?

# %%
with xr.set_options(display_style="html"):
    display(newds.mean())
# Out:
# <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#   * spatial_ref  int64 0
# Data variables:
#     blue         float64 3.52
#     green        float64 33.45
# Indexes:
#     spatial_ref  CRSIndex: EPSG:32722

# %% [markdown]
# ## groupby with flox needs to propagate indexes.
#
# flox is worse. Not surprising.

# %%
with xr.set_options(use_flox=True):
    result = newds.groupby("time.month").mean()
result
# Out:
# <xarray.Dataset>
# Dimensions:      (month: 1, y: 10, x: 10)
# Coordinates:
#   * x            (x) float64 4.663e+05 4.663e+05 ... 4.663e+05 4.663e+05
#   * y            (y) float64 8.085e+06 8.085e+06 ... 8.085e+06 8.085e+06
#     spatial_ref  int64 0
#   * month        (month) int64 12
# Data variables:
#     blue         (month, y, x) float64 6.427 5.988 0.851 ... 4.296 3.538 2.725
#     green        (month, y, x) float64 17.03 41.3 17.3 ... 35.93 42.39 35.6
# Attributes:
#     coordinates:  spatial_ref

# %%
with xr.set_options(use_flox=False):
    result = newds.groupby("time.month").mean()
result
# Out:
# <xarray.Dataset>
# Dimensions:      (month: 1, y: 10, x: 10)
# Coordinates:
#   * x            (x) float64 4.663e+05 4.663e+05 ... 4.663e+05 4.663e+05
#   * y            (y) float64 8.085e+06 8.085e+06 ... 8.085e+06 8.085e+06
#   * spatial_ref  int64 0
#   * month        (month) int64 12
# Data variables:
#     blue         (month, y, x) float64 6.427 5.988 0.851 ... 4.296 3.538 2.725
#     green        (month, y, x) float64 17.03 41.3 17.3 ... 35.93 42.39 35.6
# Indexes:
#     x            CRSIndex: EPSG:32722
#     y            CRSIndex: EPSG:32722
#     spatial_ref  CRSIndex: EPSG:32722
# Attributes:
#     coordinates:  spatial_ref

# %% [markdown]
# ## alignment
#
# ### Create a reprojected dataset that should not align

# %%
# oops lost index
reprojected = newds.rio.reproject("EPSG:4326")
reprojected
# Out:
# <xarray.Dataset>
# Dimensions:      (x: 10, y: 10, time: 2)
# Coordinates:
#   * x            (x) float64 -51.32 -51.32 -51.32 ... -51.32 -51.32 -51.32
#   * y            (y) float64 -17.32 -17.32 -17.32 ... -17.32 -17.32 -17.32
#   * time         (time) object 2016-12-19 10:27:29.687763 2016-12-29 12:52:42...
#     spatial_ref  int64 0
# Data variables:
#     blue         (time, y, x) float64 6.611 5.581 0.3996 ... 3.491 5.056 3.368
#     green        (time, y, x) float64 7.921 66.15 30.1 ... 21.76 27.29 18.41
# Attributes:
#     coordinates:  spatial_ref

# %%
# set CRSIndex again; RIO could do this automatically
reprojected = (
    ds.rio.reproject("EPSG:4326")
    .drop_indexes(["x", "y"])
    .set_xindex(("x", "y", "spatial_ref"), CRSIndex)
)
reprojected
# Out:
# <xarray.Dataset>
# Dimensions:      (x: 10, y: 10, time: 2)
# Coordinates:
#   * time         (time) object 2016-12-19 10:27:29.687763 2016-12-29 12:52:42...
#   * x            (x) float64 -51.32 -51.32 -51.32 ... -51.32 -51.32 -51.32
#   * y            (y) float64 -17.32 -17.32 -17.32 ... -17.32 -17.32 -17.32
#   * spatial_ref  int64 0
# Data variables:
#     blue         (time, y, x) float64 6.611 5.581 0.3996 ... 3.491 5.056 3.368
#     green        (time, y, x) float64 7.921 66.15 30.1 ... 21.76 27.29 18.41
# Indexes:
#     x            CRSIndex: EPSG:4326
#     y            CRSIndex: EPSG:4326
#     spatial_ref  CRSIndex: EPSG:4326
# Attributes:
#     coordinates:  spatial_ref

# %% [markdown]
# ### default join="outer"
#
# Note nice error message!

# %%
xr.align(reprojected, newds)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [15], line 1
# ----> 1 xr.align(reprojected, newds)
#
# File ~/mambaforge/envs/xarray-release/lib/python3.10/site-packages/xarray/core/alignment.py:771, in align(join, copy, indexes, exclude, fill_value, *objects)
#     575 """
#     576 Given any number of Dataset and/or DataArray objects, returns new
#     577 objects with aligned indexes and dimension sizes.
#    (...)
#     761
#     762 """
#     763 aligner = Aligner(
#     764     objects,
#     765     join=join,
#    (...)
#     769     fill_value=fill_value,
#     770 )
# --> 771 aligner.align()
#     772 return aligner.results
#
# File ~/mambaforge/envs/xarray-release/lib/python3.10/site-packages/xarray/core/alignment.py:558, in Aligner.align(self)
#     556 self.find_matching_unindexed_dims()
#     557 self.assert_no_index_conflict()
# --> 558 self.align_indexes()
#     559 self.assert_unindexed_dim_sizes_equal()
#     561 if self.join == "override":
#
# File ~/mambaforge/envs/xarray-release/lib/python3.10/site-packages/xarray/core/alignment.py:411, in Aligner.align_indexes(self)
#     404     raise ValueError(
#     405         "cannot align objects with join='exact' where "
#     406         "index/labels/sizes are not equal along "
#     407         "these coordinates (dimensions): "
#     408         + ", ".join(f"{name!r} {dims!r}" for name, dims in key[0])
#     409     )
#     410 joiner = self._get_index_joiner(index_cls)
# --> 411 joined_index = joiner(matching_indexes)
#     412 if self.join == "left":
#     413     joined_index_vars = matching_index_vars[0]
#
# Cell In [2], line 106, in CRSIndex.join(self, other, how)
#     104 def join(self, other, how="inner"):
#     105     if self._crs != other._crs:
# --> 106         raise ValueError(
#     107             "Cannot align or join objects with different CRS. "
#     108             f"Received {self._crs.name!r} and {other._crs.name!r}"
#     109         )
#     111     new_indexes = {
#     112         k: v.join(other._indexes[k], how=how) for k, v in self._indexes.items()
#     113     }
#     114     # create new spatial_ref here.
#
# ValueError: Cannot align or join objects with different CRS. Received 'WGS 84' and 'WGS 84 / UTM zone 22S'

# %% [markdown]
# ### join="exact" test out __equals__
#
# Could have nicer error message

# %%
xr.align(reprojected, newds, join="exact")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [16], line 1
# ----> 1 xr.align(reprojected, newds, join="exact")
#
# File ~/mambaforge/envs/xarray-release/lib/python3.10/site-packages/xarray/core/alignment.py:771, in align(join, copy, indexes, exclude, fill_value, *objects)
#     575 """
#     576 Given any number of Dataset and/or DataArray objects, returns new
#     577 objects with aligned indexes and dimension sizes.
#    (...)
#     761
#     762 """
#     763 aligner = Aligner(
#     764     objects,
#     765     join=join,
#    (...)
#     769     fill_value=fill_value,
#     770 )
# --> 771 aligner.align()
#     772 return aligner.results
#
# File ~/mambaforge/envs/xarray-release/lib/python3.10/site-packages/xarray/core/alignment.py:558, in Aligner.align(self)
#     556 self.find_matching_unindexed_dims()
#     557 self.assert_no_index_conflict()
# --> 558 self.align_indexes()
#     559 self.assert_unindexed_dim_sizes_equal()
#     561 if self.join == "override":
#
# File ~/mambaforge/envs/xarray-release/lib/python3.10/site-packages/xarray/core/alignment.py:404, in Aligner.align_indexes(self)
#     402 if need_reindex:
#     403     if self.join == "exact":
# --> 404         raise ValueError(
#     405             "cannot align objects with join='exact' where "
#     406             "index/labels/sizes are not equal along "
#     407             "these coordinates (dimensions): "
#     408             + ", ".join(f"{name!r} {dims!r}" for name, dims in key[0])
#     409         )
#     410     joiner = self._get_index_joiner(index_cls)
#     411     joined_index = joiner(matching_indexes)
#
# ValueError: cannot align objects with join='exact' where index/labels/sizes are not equal along these coordinates (dimensions): 'x' ('x',), 'y' ('y',), 'spatial_ref' ()

# %% [markdown]
# ### BROKEN: Successfully align with a copy of itself

# %%
copy = newds.copy(deep=True)
copy
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 2, x: 10, y: 10)
# Coordinates:
#   * time         (time) object 2016-12-19 10:27:29.687763 2016-12-29 12:52:42...
#   * x            (x) float64 4.663e+05 4.663e+05 ... 4.663e+05 4.663e+05
#   * y            (y) float64 8.085e+06 8.085e+06 ... 8.085e+06 8.085e+06
#   * spatial_ref  int64 0
# Data variables:
#     blue         (time, y, x) float64 6.611 5.581 0.3996 ... 3.491 5.056 3.368
#     green        (time, y, x) float64 7.921 66.15 30.1 ... 21.76 27.29 18.41
# Indexes:
#     x            CRSIndex: EPSG:32722
#     y            CRSIndex: EPSG:32722
#     spatial_ref  CRSIndex: EPSG:32722
# Attributes:
#     coordinates:  spatial_ref

# %%
xr.align(copy, newds)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [19], line 1
# ----> 1 xr.align(copy, newds)
#
# File ~/mambaforge/envs/xarray-release/lib/python3.10/site-packages/xarray/core/alignment.py:771, in align(join, copy, indexes, exclude, fill_value, *objects)
#     575 """
#     576 Given any number of Dataset and/or DataArray objects, returns new
#     577 objects with aligned indexes and dimension sizes.
#    (...)
#     761
#     762 """
#     763 aligner = Aligner(
#     764     objects,
#     765     join=join,
#    (...)
#     769     fill_value=fill_value,
#     770 )
# --> 771 aligner.align()
#     772 return aligner.results
#
# File ~/mambaforge/envs/xarray-release/lib/python3.10/site-packages/xarray/core/alignment.py:558, in Aligner.align(self)
#     556 self.find_matching_unindexed_dims()
#     557 self.assert_no_index_conflict()
# --> 558 self.align_indexes()
#     559 self.assert_unindexed_dim_sizes_equal()
#     561 if self.join == "override":
#
# File ~/mambaforge/envs/xarray-release/lib/python3.10/site-packages/xarray/core/alignment.py:396, in Aligner.align_indexes(self)
#     394 else:
#     395     if len(matching_indexes) > 1:
# --> 396         need_reindex = self._need_reindex(
#     397             dims,
#     398             list(zip(matching_indexes, matching_index_vars)),
#     399         )
#     400     else:
#     401         need_reindex = False
#
# File ~/mambaforge/envs/xarray-release/lib/python3.10/site-packages/xarray/core/alignment.py:347, in Aligner._need_reindex(self, dims, cmp_indexes)
#     336 """Whether or not we need to reindex variables for a set of
#     337 matching indexes.
#     338
#    (...)
#     344
#     345 """
#     346 has_unindexed_dims = any(dim in self.unindexed_dim_sizes for dim in dims)
# --> 347 return not (indexes_all_equal(cmp_indexes)) or has_unindexed_dims
#
# File ~/mambaforge/envs/xarray-release/lib/python3.10/site-packages/xarray/core/indexes.py:1402, in indexes_all_equal(elements)
#    1400 if same_type:
#    1401     try:
# -> 1402         not_equal = any(
#    1403             not indexes[0].equals(other_idx) for other_idx in indexes[1:]
#    1404         )
#    1405     except NotImplementedError:
#    1406         not_equal = check_variables()
#
# File ~/mambaforge/envs/xarray-release/lib/python3.10/site-packages/xarray/core/indexes.py:1403, in <genexpr>(.0)
#    1400 if same_type:
#    1401     try:
#    1402         not_equal = any(
# -> 1403             not indexes[0].equals(other_idx) for other_idx in indexes[1:]
#    1404         )
#    1405     except NotImplementedError:
#    1406         not_equal = check_variables()
#
# Cell In [2], line 99, in CRSIndex.equals(self, other)
#      96 def equals(self, other):
#      97     result = self._crs is other._crs or (
#      98         self._crs == other._crs
# ---> 99         and self._indexes["x"].equals(other._indexes["x"])
#     100         and self._indexes["y"].equals(other._indexes["y"])
#     101     )
#     102     return result
#
# File ~/mambaforge/envs/xarray-release/lib/python3.10/site-packages/xarray/core/indexes.py:490, in PandasIndex.equals(self, other)
#     488 if not isinstance(other, PandasIndex):
#     489     return False
# --> 490 return self.index.equals(other.index) and self.dim == other.dim
#
# AttributeError: 'PandasIndex' object has no attribute 'index'

# %% [markdown]
# ### Align with subsets

# %%
xr.align(newds.isel(x=[5, 6]), newds, join="outer")
# Out:
# (<xarray.Dataset>
#  Dimensions:      (time: 2, x: 10, y: 10)
#  Coordinates:
#    * time         (time) object 2016-12-19 10:27:29.687763 2016-12-29 12:52:42...
#    * x            (x) float64 4.663e+05 4.663e+05 ... 4.663e+05 4.663e+05
#    * y            (y) float64 8.085e+06 8.085e+06 ... 8.085e+06 8.085e+06
#    * spatial_ref  int64 0
#  Data variables:
#      blue         (time, y, x) float64 nan nan nan nan nan ... 1.888 nan nan nan
#      green        (time, y, x) float64 nan nan nan nan nan ... 12.96 nan nan nan
#  Indexes:
#      x            CRSIndex: EPSG:32722
#      y            CRSIndex: EPSG:32722
#      spatial_ref  CRSIndex: EPSG:32722
#  Attributes:
#      coordinates:  spatial_ref,
#  <xarray.Dataset>
#  Dimensions:      (time: 2, x: 10, y: 10)
#  Coordinates:
#    * time         (time) object 2016-12-19 10:27:29.687763 2016-12-29 12:52:42...
#    * x            (x) float64 4.663e+05 4.663e+05 ... 4.663e+05 4.663e+05
#    * y            (y) float64 8.085e+06 8.085e+06 ... 8.085e+06 8.085e+06
#    * spatial_ref  int64 0
#  Data variables:
#      blue         (time, y, x) float64 6.611 5.581 0.3996 ... 3.491 5.056 3.368
#      green        (time, y, x) float64 7.921 66.15 30.1 ... 21.76 27.29 18.41
#  Indexes:
#      x            CRSIndex: EPSG:32722
#      y            CRSIndex: EPSG:32722
#      spatial_ref  CRSIndex: EPSG:32722
#  Attributes:
#      coordinates:  spatial_ref)

# %%
xr.align(newds.isel(x=[5, 6]), newds, join="inner")
# Out:
# (<xarray.Dataset>
#  Dimensions:      (time: 2, x: 2, y: 10)
#  Coordinates:
#    * time         (time) object 2016-12-19 10:27:29.687763 2016-12-29 12:52:42...
#    * x            (x) float64 4.663e+05 4.663e+05
#    * y            (y) float64 8.085e+06 8.085e+06 ... 8.085e+06 8.085e+06
#    * spatial_ref  int64 0
#  Data variables:
#      blue         (time, y, x) float64 4.76 5.078 3.228 ... 3.218 4.871 1.888
#      green        (time, y, x) float64 11.54 14.43 44.91 ... 50.6 48.73 12.96
#  Indexes:
#      x            CRSIndex: EPSG:32722
#      y            CRSIndex: EPSG:32722
#      spatial_ref  CRSIndex: EPSG:32722
#  Attributes:
#      coordinates:  spatial_ref,
#  <xarray.Dataset>
#  Dimensions:      (time: 2, x: 2, y: 10)
#  Coordinates:
#    * time         (time) object 2016-12-19 10:27:29.687763 2016-12-29 12:52:42...
#    * x            (x) float64 4.663e+05 4.663e+05
#    * y            (y) float64 8.085e+06 8.085e+06 ... 8.085e+06 8.085e+06
#    * spatial_ref  int64 0
#  Data variables:
#      blue         (time, y, x) float64 4.76 5.078 3.228 ... 3.218 4.871 1.888
#      green        (time, y, x) float64 11.54 14.43 44.91 ... 50.6 48.73 12.96
#  Indexes:
#      x            CRSIndex: EPSG:32722
#      y            CRSIndex: EPSG:32722
#      spatial_ref  CRSIndex: EPSG:32722
#  Attributes:
#      coordinates:  spatial_ref)
